# %%
from IPython.core.display import display, HTML
display(HTML("<style>"
    + "#notebook { padding-top:0px !important; } " 
    + ".container { width:100% !important; } "
    + ".end_space { min-height:0px !important; } "
    + "</style>"))
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } </style>

# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

def fitsPlotter(fitsFile, ext = 0, figsize=(20,10)):
    image_file = get_pkg_data_filename(fitsFile)
    print fits.info(image_file)
    image_data = fits.getdata(image_file, ext = ext)
    print type(image_data)
    plt.figure(figsize = figsize)
    plt.imshow(image_data, cmap = 'gray')
    plt.colorbar()

# %%
def fits_to_Numpy(fitsFile, ext = 0):
    image_file = get_pkg_data_filename(fitsFile)
    print fits.info(image_file)
    image_data = fits.getdata(image_file, ext = ext)
#     print type(image_data)
    return image_data

# %%
# areas = fits_to_Numpy('./output/testAreas.fits')

# %%
# plt.figure(figsize = (20,10))
# plt.imshow(areas, cmap = 'gray')
# plt.colorbar()

# %%
fitsPlotter('./output/testAreas.fits')
fitsPlotter('./output/testImage.fits')
# Out:
# Filename: output/testAreas.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (17, 17)   float32
# None
# <type 'numpy.ndarray'>
# Filename: output/testImage.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (17, 17)   float32
# None
# <type 'numpy.ndarray'>

# %%
fits.info(image_file)
# Out:
# Filename: /Users/jeffralyjz/.astropy/cache/download/py2/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
image_data = fits.getdata(image_file, ext=0)

# %%
print(image_data.shape)
# Out:
# (893, 891)

# %%
plt.figure()
plt.imshow(image_data, cmap='gray')
plt.colorbar()
